# %%
#importing required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import glob, os

#set max display columns to 500 so that all columns are visible when a dataframe is printed
pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Part 1 - A

# %%
# Set maximum columns to display 500
pd.set_option('display.max_columns', 500)

#Read the csv file and convert it into dataframe
stateGDP = pd.read_csv(r'C:\Users\ACER\Desktop\MS\GDP Assignment\Data 1 A GSDP.csv')

#Replace all the NAN values with 0
stateGDP.fillna(0, inplace = True)

#Drop the Union Territories
stateGDP = stateGDP.drop(columns = ['Delhi', 'Puducherry','Chandigarh','Andaman & Nicobar Islands','West Bengal1'])

#Creating duplicate of dataframe
stateTotalGDP = stateGDP

stateGDP
# Out:
#                     Items  Description Duration  Andhra Pradesh   \
# 0   GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1   GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2   GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3   GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4   GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5   GSDP - CURRENT PRICES (` in Crore)  2016-17        699307.00
# 6        (% Growth over previous year)  2012-13             8.43
# 7        (% Growth over previous year)  2013-14            12.85
# 8        (% Growth over previous year)  2014-15            13.40
# 9        (% Growth over previous year)  2015-16            15.85
# 10       (% Growth over previous year)  2016-17            14.65
#
#     Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa  \
# 0            11063.00  143175.00  247144.00     158074.00  42367.00
# ...

# %%
#Initialiing "row" list containing index those needs to be dropped
rows = [0,1,2,3,4,5]
stateGDP = stateGDP.drop(rows)

durationList = list(stateGDP['Duration'])

#Drop the "Items Description" column
stateGDP = stateGDP.drop(columns = ['Items  Description'])

# %%
stateGDP.index = range(1,stateGDP.shape[0]+1)
stateGDP
# Out:
#   Duration  Andhra Pradesh   Arunachal Pradesh  Assam  Bihar  Chhattisgarh  \
# 1  2012-13             8.43              13.41   9.56  14.25         12.30
# 2  2013-14            12.85              16.38  13.31  12.30         16.44
# 3  2014-15            13.40              14.79  11.45  17.92         13.69
# 4  2015-16            15.85              12.07  13.19  10.59         10.98
# 5  2016-17            14.65               0.00   0.00   0.00         11.26
#
#      Goa  Gujarat  Haryana  Himachal Pradesh  Jammu & Kashmir  Jharkhand  \
# 1 -10.02    17.69    16.63             13.89            11.31      15.77
# 2  -5.77    11.47    15.45             14.42            10.09       7.92
# 3  13.12    10.82     9.18             10.14             4.70      15.14
# 4  10.75    11.09    10.91              0.00            17.91      11.44
# 5   0.00     0.00    12.82              0.00             0.00       0.00
#
#    Karnataka  Kerala  Madhya Pradesh  Maharashtra  Manipur  Meghalaya  \
# ...

# %%
plt.figure(figsize=(15,50), facecolor='white')


slope_dictionay = {}

# plot numbering starts at 1, not 0
plot_number = 1
for i in range(1, len(stateGDP.columns)):
    # Inside of an image that's a 15x13 grid, put this
    # graph in the in the plot_number slot.
    ax = plt.subplot(15, 2, plot_number)
    m,c = np.polyfit(stateGDP.index, stateGDP[stateGDP.columns[i]],1)
    slope_dictionay.update([(stateGDP.columns[i],m)])
    ax.scatter(x =stateGDP.index , y= stateGDP.columns[i] , data = stateGDP )
    plt.plot( stateGDP.index,  m*stateGDP.index+c, '--r')
    ax.set_title(stateGDP.columns[i])
    
    # Go to the next plot for the next loop
    plot_number = plot_number + 1
plt.tight_layout()

# %%
slopeDF = pd.DataFrame.from_dict(slope_dictionay, orient='index', columns=['slopes'])
slopeDF = slopeDF.sort_values(by = 'slopes', ascending=False)

# %% [markdown]
# Comparing the growth rate of Two States:
#
# When using "Best Fit Line", we needed to find the slopes from available data. Using these slopes plotted the Best fit line.
# Also, the slopes are either Positive or Negative.
# This tells us that if slope of data present for a given state is Positive then GDP for that state is progressing else GDP is decreasing.

# %%
#Visual representation of the States as per decreasing growth rate of GDP
slopeDF.plot.bar()

# %% [markdown]
# By observing above Bar graph, we can easily compare growth rate of any two states

# %% [markdown]
# #### Top 3 Fastest and Bottom 3 Slowest growing states

# %% [markdown]
# When average of growth rates over previous years is calculated, it will provide the states those are constantly growing over the years and the states those are not growing.
#
# In the available data set, % Growth values for states are present.
# Using these values, average for each state is calculated.

# %%
stateGDP = stateGDP.drop(columns = ['Duration']) 
stateGDP = stateGDP.T

# %%
stateGDP['Average Growth Rate'] = stateGDP.mean(axis = 1, skipna = True)
stateGDP = stateGDP.sort_values('Average Growth Rate',ascending=False)
print(stateGDP)

plt.figure(figsize=(12,8))
plt.bar(stateGDP.index, stateGDP['Average Growth Rate'] )
plt.xlabel('States', fontsize=10)
plt.ylabel('Average Growth Rate', fontsize=10)
plt.xticks( fontsize=8, rotation=90)
# Out:
#                        1      2      3      4      5  Average Growth Rate
# Madhya Pradesh     20.71  14.91  10.11  12.86  17.74               15.266
# Andhra Pradesh      8.43  12.85  13.40  15.85  14.65               13.036
# Haryana            16.63  15.45   9.18  10.91  12.82               12.998
# Chhattisgarh       12.30  16.44  13.69  10.98  11.26               12.934
# Telangana          11.70  12.63  13.05  12.61  13.67               12.732
# Tamil Nadu         13.84  13.51  12.51  10.99  10.40               12.250
# All_India GDP      13.86  12.97  10.65   9.99  11.52               11.798
# Karnataka          14.56  18.24  12.70  11.42   0.00               11.384
# Arunachal Pradesh  13.41  16.38  14.79  12.07   0.00               11.330
# Bihar              14.25  12.30  17.92  10.59   0.00               11.012
# Odisha             13.34  12.95  10.37   6.19  10.85               10.740
# Gujarat            17.69  11.47  10.82  11.09   0.00               10.214
# ...

# %% [markdown]
# With referrence to the above graph
#
# Top 3 Fastest Growing States:
#     1. Madhya Pradesh
#     2. Andhra Pradesh
#     3. Haryana
#
# Bottom 3 Slowest Growing States:
#     1. Goa
#     2. Punjab
#     3. Manipur

# %% [markdown]
# #### Nation's Growth Rate

# %% [markdown]
# As observed in the bar graph visual, Nation's growth rate is represented by "All India GDP".
#
# Referrencing the table, the nations growth rate is 11.798%.

# %% [markdown]
# #### Maharashtra's (Home State) Growth Rate

# %% [markdown]
# From bar graph visual and values provided by table, Maharashtra's growth rate over the years is 7.262%.

# %% [markdown]
# #### Home State VS Nation's Growth Rate

# %% [markdown]
# When observed in the bar graph visualization, we can say that India's GDP growth rate is better than Maharashtra's GDP growth rate.
#
# Maharashtra's GDP growth rate is 7.262 % and India's growth rate is 11.798 %.

# %% [markdown]
# ### Plot the total GDP of the states for the year 2015-16:

# %%
stateTotalGDP = stateTotalGDP[stateTotalGDP['Duration'] == '2015-16']

# %%
stateTotalGDP = stateTotalGDP.drop([9])
stateTotalGDP
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana  Himachal Pradesh  Jammu & Kashmir  Jharkhand  Karnataka  \
# 4  485184.0               0.0         118387.0   241955.0  1027068.0
#
#      Kerala  Madhya Pradesh  Maharashtra  Manipur  Meghalaya  Mizoram  \
# 4  588337.0        543975.0          0.0      0.0    26745.0      0.0
#
#    Nagaland    Odisha  Punjab  Rajasthan   Sikkim  Tamil Nadu  Telangana  \
# 4       0.0  341887.0     0.0        0.0  16637.0   1212668.0   575631.0
#
#    Tripura  Uttar Pradesh  Uttarakhand  All_India GDP
# 4      0.0      1153795.0     184091.0     13675331.0

# %%
durationList = list(stateTotalGDP['Duration'])
print(durationList)
# Out:
# ['2015-16']

# %%
stateTotalGDP = stateTotalGDP.drop(columns = ['Items  Description', 'Duration'])

# %%
stateTotalGDP = stateTotalGDP.T
stateTotalGDP = stateTotalGDP.sort_values(by = [4], ascending = False)
stateTotalGDP.columns = durationList
stateTotalGDP = stateTotalGDP.drop(index = 'All_India GDP')

# %%
stateTotalGDP.plot.bar(figsize=(15,5))
plt.xlabel("States", fontsize = 10)
plt.ylabel("Total GDP", fontsize = 10)
plt.title("Total GDP of the States for the year 2015-16")
# Out:
# Text(0.5, 1.0, 'Total GDP of the States for the year 2015-16')

# %% [markdown]
# Here "Bar Graph" is plotted which gives distribution of Total GDP of States for Year "2015-16" as it will be easier for anyone to understand just by looking at the visualization.
#
# Also we can rank the states with decreasing order of toatl GDP in Bar graph. Due to which "bar graph" is preferred here over other graphs.

# %% [markdown]
# #### Top 5 and bottom 5 states based on Total GDP

# %% [markdown]
# Top 5 States:
#     1. Tamil Nadu
#     2. Uttar Pradesh
#     3. Karnataka
#     4. Gujarat
#     5. Andhra Pradesh
#
#
#
# Since no data is available for below states, these states can not be ranked as bottom states:
#     1. Tripura
#     2. Mizoram
#     3. Rajasthan
#     4. Punjab
#     5. Nagaland
#     6. Himachal Pradesh
#     7. Maharashtra
#
# Bottom 5 States:
#     1. Sikkim
#     2. Arunachal Pradesh
#     3. Meghalaya
#     4. Goa
#     5. Jammu And Kashmir
#
#
# We can see that States like Goa, Jammu And Kashmir, Sikkim, Meghalaya and  Arunachal Pradesh are ranked to the bottom as clearly they are not performing good.
#
# If we see the % Growth over previous years for Goa, we can see that GDP for Goa was performing very bad over the years, and has started recovering.
#
# Jammu And Kashmir has been ranked at the bottom as well because the travel industry is affected every time there is some situations at the border and affecting the GDP.

# %% [markdown]
# # Part 1 - B

# %%
# Path where all the files are stored
path = r'C:\Users\ACER\Desktop\MS\GDP Assignment\GDP Data' 

# Reading all the paths
all_files = glob.glob(path + "/*.csv")

states_list = []

# Iterating over all the files and then storing them in a single dataframe
for filename in all_files:
    GSVA_data = pd.read_csv(filename, encoding = 'cp1252')
    
    #Choose "Item" and "2014-15" columns only
    GSVA_data_states = GSVA_data[['Item', '2014-15']] 
    
    # Transform the dataframe
    GSVA_data_states = GSVA_data_states.T
    
    # Create a object with first row as values
    new_column_headers = GSVA_data_states.iloc[0]
    
    # Set created object as heder for the new dataframe
    GSVA_data_states.columns = new_column_headers
    GSVA_data_states = GSVA_data_states[1:]
    
    # Split the filename and extract the state name
    GSVA_data_states.loc[:, 'State'] = filename.split('/')[-1].split('-')[1]
    states_list.append(GSVA_data_states)


states_list
# Out:
# [Item    Agriculture, forestry and fishing    Crops Livestock  \
#  2014-15                          14819416  7893514   4309078
#
#  Item    Forestry and logging Fishing and aquaculture Mining and quarrying  \
#  2014-15               346160                 2270664              1484300
#
#  Item      Primary Manufacturing  \
#  2014-15  16303716       4672266
#
#  Item    Electricity, gas, water supply & other utility services Construction  \
#  2014-15                                            1151729           4664889
#
#  Item    Secondary Trade, repair, hotels and restaurants  \
#  2014-15  10488884                               4233400
#
#  Item    Trade & repair services Hotels & restaurants  \
#  2014-15                 3716000               517400
#
#  Item    Transport, storage, communication & services related to broadcasting  \
#  2014-15                                            5076984
#
#  Item    Railways Road transport Water transport Air transport  \
# ...

# %%
index_df = pd.concat(states_list, axis = 0, ignore_index = True , sort=True)
import warnings
warnings.filterwarnings('ignore')
index_df.fillna(0, inplace = True)
index_df
# Out:
#     Agriculture, forestry and fishing  Air transport  \
# 0                          14819416.0        14900.0
# 1                            686117.0            0.0
# 2                           3855548.0        26223.0
# 3                           7951890.0        13599.0
# 4                             16233.0        12391.0
# 5                           3948847.0         9507.0
# 6                            250568.0       420460.0
# 7                            308507.0        46359.0
# 8                          13769969.0            0.0
# 9                           8015238.0            0.0
# 10                          1514981.0         3979.0
# 11                          3211065.0         6716.0
# 12                         11219422.0       171785.0
# 13                          5930617.0       125029.0
# 14                         16235647.0        26746.0
# 15                         16475655.0       174188.0
# 16                           383140.0         6288.0
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

#Set "State" as index name
index_df.set_index('State', inplace = True)
index_df.columns
# Out:
# Index(['Agriculture, forestry and fishing', 'Air transport',
#        'Communication & services related to broadcasting', 'Construction',
#        'Crops', 'Electricity, gas, water supply & other utility services',
#        'Financial services', 'Fishing and aquaculture', 'Forestry and logging',
#        'Gross State Domestic Product', 'Hotels & restaurants', 'Livestock',
#        'Manufacturing', 'Mining and quarrying', 'Other services',
#        'Per Capita GSDP (Rs.)', 'Population ('00)', 'Primary',
#        'Public administration', 'Railways',
#        'Real estate, ownership of dwelling & professional services',
#        'Road transport', 'Road transport*', 'Road transport**', 'Secondary',
#        'Services incidental to transport', 'Services incidental to transport*',
#        'Storage', 'Subsidies on products', 'TOTAL GSVA at basic prices',
#        'Taxes on Products', 'Tertiary', 'Trade & repair services',
# ...

# %%
#Dropping Union Territories

final_states_GSVA = index_df.T

#Drop the union territories
final_states_GSVA = final_states_GSVA.drop(columns = ['Delhi', 'Chandigarh', 'Puducherry'])
final_states_GSVA

# Transfrom and create new dataframe
index_df = final_states_GSVA.T
index_df
# Out:
#                    Agriculture, forestry and fishing  Air transport  \
# State
# Andhra_Pradesh                            14819416.0        14900.0
# Arunachal_Pradesh                           686117.0            0.0
# Assam                                      3855548.0        26223.0
# Bihar                                      7951890.0        13599.0
# Chhattisgarh                               3948847.0         9507.0
# Goa                                         308507.0        46359.0
# Gujarat                                   13769969.0            0.0
# Haryana                                    8015238.0            0.0
# Himachal_Pradesh                           1514981.0         3979.0
# Jharkhand                                  3211065.0         6716.0
# Karnataka                                 11219422.0       171785.0
# Kerala                                     5930617.0       125029.0
# Madhya_Pradesh                            16235647.0        26746.0
# ...

# %%
# Set the datatype of column as float
index_df['Per Capita GSDP (Rs.)'] = index_df['Per Capita GSDP (Rs.)'].astype(float)

# %%
# Extract the "Per Capita GSDP" column only
per_capita_GDP_states= index_df[['Per Capita GSDP (Rs.)']]

# Sort the dataframe by "States" column
per_capita_GDP_states = per_capita_GDP_states.sort_values(by = ['Per Capita GSDP (Rs.)'], ascending = False)

# %%
per_capita_GDP_states.plot.bar(figsize=(20,10))
plt.ylabel('Per Capita GSDP (Rs.)',fontsize=10)
plt.xlabel('States',fontsize=10)
plt.title('GDP per capita for all the states')
# Out:
# Text(0.5, 1.0, 'GDP per capita for all the states')

# %%
# Top 5 States based on the GDP per capita
per_capita_GDP_states.nlargest(5,'Per Capita GSDP (Rs.)')
# Out:
#              Per Capita GSDP (Rs.)
# State
# Goa                       271793.0
# Sikkim                    240274.0
# Haryana                   164077.0
# Kerala                    154778.0
# Uttarakhand               153076.0

# %%
# Bottom 5 States based on the GDP per capita
per_capita_GDP_states.nsmallest(5,'Per Capita GSDP (Rs.)')
# Out:
#                Per Capita GSDP (Rs.)
# State
# Bihar                        33954.0
# Uttar_Pradesh                49450.0
# Manipur                      58442.0
# Assam                        60621.0
# Jharkhand                    62091.0

# %%
#the ratio of the highest per capita GDP to the lowest per capita GDP.

per_Capita_Ratio = per_capita_GDP_states['Per Capita GSDP (Rs.)'].max()/per_capita_GDP_states['Per Capita GSDP (Rs.)'].min()
print("The ratio of the highest per capita GDP to the lowest per capita GDP is : {0}" .format(per_Capita_Ratio))
# Out:
# The ratio of the highest per capita GDP to the lowest per capita GDP is : 8.004741709371503

# %%
#Plot the percentage contribution of the primary, secondary and tertiary sectors 
#as a percentage of the total GDP for all the states.

index_df
index_df['% Primary'] = 100 *(index_df['Primary']/index_df['Gross State Domestic Product'])
index_df['% Secondary'] = 100 *(index_df['Secondary']/index_df['Gross State Domestic Product']) 
index_df['% Tertiary'] = 100 *(index_df['Tertiary']/index_df['Gross State Domestic Product'])

# %%
sectors = index_df.iloc[:,-3:]
plot = sectors.plot(kind = 'bar', stacked = True, figsize = (20,10))
plt.title('% Sector Contributions')
plt.xlabel('States', fontsize = 10)
plt.ylabel('Sectionwize Percentage Contribution', fontsize = 10)
plt.legend(fontsize = 10)
plt.legend( bbox_to_anchor =(1,0.5))

# %% [markdown]
# Bar Stacked Chart is suitable in this scenario as we are comparing 3 parameters of all the states.
# Also the 3 Paramters (% Primary, % Secondary, % Tertiary) are part of the "Total GDP" (part of the same quantity). Hence using Stacked chart will let us easily compare the values with other states.

# %% [markdown]
# Why is (Primary + Secondary + Tertiary) not equal to total GDP?
#
# Since (Primary + Secondary + Tertiary) is Nation's way of income from industries. There are other factors also those contribute to the total GDP such as Taxes collected, Income form exproting goods as well as debts to global banks.
# Which is why (Primary + Secondary + Tertiary) is not equal to total GDP.

# %%
index_df['Percentile_rank using GSDP'] = index_df['Gross State Domestic Product'].rank(pct=True)
index_df2 = index_df[['Percentile_rank using GSDP','% Primary','Gross State Domestic Product']].corr()
index_df2


# Plot a heatmap which will give the visually represent the correlation between values
# figure size
plt.figure(figsize=(10,8))

# heatmap
sns.heatmap(index_df2, cmap="YlGnBu", annot=True)
plt.show()

# %%
C4_quantile_value = index_df['Per Capita GSDP (Rs.)'].quantile(.2)
C3_quantile_value = index_df['Per Capita GSDP (Rs.)'].quantile(.5)
C2_quantile_value = index_df['Per Capita GSDP (Rs.)'].quantile(.85)
C1_quantile_value = index_df['Per Capita GSDP (Rs.)'].quantile(1)

# %%
Tag = []

for row in index_df['Per Capita GSDP (Rs.)']:
    if row >= C2_quantile_value:
        Tag.append("C1")
    elif row >= C3_quantile_value and row < C2_quantile_value:
        Tag.append("C2")
    elif row >= C4_quantile_value and row < C3_quantile_value:
        Tag.append("C3")
    elif row < C4_quantile_value :
        Tag.append("C4")
        
Tag
# Out:
# ['C2',
#  'C2',
#  'C4',
#  'C4',
#  'C3',
#  'C1',
#  'C2',
#  'C1',
#  'C2',
#  'C4',
#  'C2',
#  'C1',
#  'C4',
#  'C2',
#  'C4',
#  'C3',
#  'C3',
#  'C3',
#  'C3',
#  'C2',
#  'C3',
#  'C1',
#  'C2',
#  'C2',
#  'C3',
#  'C2',
#  'C4']

# %%
#Creating new column "Tag" and labelling the states as C1, C2, C3, C4
index_df['Tag'] = Tag

#Creating a new copy of dataframe
dropout_df_data = index_df
#index_df

# %% [markdown]
# ### Find the top 3/4/5 sub-sectors

# %%
#Creating new dataframe which will have only subsector values

states_list = []

for filename in all_files:
    GSVA_data = pd.read_csv(filename, encoding = 'cp1252')
    GSVA_data_states = GSVA_data[['Item', '2014-15','S.No.']] 
    
    #Remove the columns which are not int
    GSVA_data_states = GSVA_data_states[~GSVA_data_states["S.No."].str.contains("\.")]
    
    #Remove the column having Total Values
    GSVA_data_states= GSVA_data_states[~GSVA_data_states["S.No."].str.contains("Total")]
    
    # Drop "S.No." column
    GSVA_data_states = GSVA_data_states.drop(columns = ["S.No."])
    
    #Transform the dataframe
    GSVA_data_states = GSVA_data_states.T
    new_column_headers = GSVA_data_states.iloc[0]

    GSVA_data_states.columns = new_column_headers
    GSVA_data_states = GSVA_data_states[1:]
    GSVA_data_states.loc[:, 'State'] = filename.split('/')[-1].split('-')[1]
    states_list.append(GSVA_data_states)


#print(states_list)

# %%
index_df = pd.concat(states_list, axis = 0, ignore_index = True)
import warnings
warnings.filterwarnings('ignore')
index_df.set_index('State', inplace = True)
index_df.columns
# Out:
# Index(['Agriculture, forestry and fishing', 'Construction',
#        'Electricity, gas, water supply & other utility services',
#        'Financial services', 'Gross State Domestic Product', 'Manufacturing',
#        'Mining and quarrying', 'Other services', 'Per Capita GSDP (Rs.)',
#        'Population ('00)', 'Public administration',
#        'Real estate, ownership of dwelling & professional services',
#        'Subsidies on products', 'TOTAL GSVA at basic prices',
#        'Taxes on Products', 'Trade, repair, hotels and restaurants',
#        'Transport, storage, communication & services related to broadcasting'],
#       dtype='object')

# %%
#Dropping Union Territories

final_states_GSVA = index_df.T
final_states_GSVA = final_states_GSVA.drop(columns = ['Delhi', 'Chandigarh', 'Puducherry'])
final_states_GSVA
index_df = final_states_GSVA.T

# Replace the NA values with 0
index_df.fillna(0, inplace = True)

# %%
# Categorising the states as C1, C2, C3, C4 in new dataframe
index_df['Tag'] = Tag

# %% [markdown]
# #### Analysing the data for C1 States

# %%
#Filter out the C1 States
C1_state_df= index_df[index_df['Tag'] == 'C1']
C1_state_df = C1_state_df.T

#Drop the columns those are not Sub - Sectors
C1_state_df = C1_state_df.drop('Tag')
C1_state_df = C1_state_df.drop('Per Capita GSDP (Rs.)')
C1_state_df = C1_state_df.drop('TOTAL GSVA at basic prices')
C1_state_df = C1_state_df.drop('Taxes on Products')
C1_state_df = C1_state_df.drop('Subsidies on products')
C1_state_df = C1_state_df.drop("Population ('00)")

#Sum the values of all the states
C1_state_df['Total Conribution'] = C1_state_df.sum(axis = 1)
Total_GSDP = 0

#Take the value of total "GSDP"
Total_GSDP = C1_state_df['Total Conribution']['Gross State Domestic Product']

# Drop "GSDP" 
C1_state_df = C1_state_df.drop('Gross State Domestic Product')

#Calculate the "% Total Contribution per GSDP"
C1_state_df['% Total Conribution per GSDP'] = (C1_state_df['Total Conribution'] / Total_GSDP)*100
C1_state_df = C1_state_df.sort_values(by = ['% Total Conribution per GSDP'], ascending = False)

C1_state_df


#Finding which sectors contribute to 80% of GSDP
Sectors_contributing_upto_80 = C1_state_df.cumsum(axis = 0)
Sectors_contributing_upto_80 = Sectors_contributing_upto_80[Sectors_contributing_upto_80['% Total Conribution per GSDP'] <= 82]
Sectors_contributing_upto_80 = Sectors_contributing_upto_80[['% Total Conribution per GSDP']] 
Sectors_contributing_upto_80
# Out:
# State                                              % Total Conribution per GSDP
# Real estate, ownership of dwelling & profession...                       14.461
# Agriculture, forestry and fishing                                       28.5803
# Trade, repair, hotels and restaurants                                   42.3103
# Manufacturing                                                           55.8085
# Construction                                                            66.8596
# Other services                                                          74.7669
# Transport, storage, communication & services re...                      81.4563

# %%
C1_state_df['% Total Conribution per GSDP'].plot.bar(figsize = (10,7))
plt.title('C1 State Total Contribution per GSDP')
plt.xlabel('Sectors', fontsize = 10)
plt.ylabel('% Total Conribution per GSDP', fontsize = 10)
# Out:
# Text(0, 0.5, '% Total Conribution per GSDP')

# %%
# Filtering C2 States
C2_state_df= index_df[index_df['Tag'] == 'C2']
C2_state_df = C2_state_df.T

C2_state_df = C2_state_df.drop('Tag')
C2_state_df = C2_state_df.drop('Per Capita GSDP (Rs.)')
C2_state_df = C2_state_df.drop('TOTAL GSVA at basic prices')
C2_state_df = C2_state_df.drop('Taxes on Products')
C2_state_df = C2_state_df.drop('Subsidies on products')
C2_state_df = C2_state_df.drop("Population ('00)")

C2_state_df['Total Conribution'] = C2_state_df.sum(axis = 1)
Total_GSDP = 0
Total_GSDP = C2_state_df['Total Conribution']['Gross State Domestic Product']
print(Total_GSDP)
C2_state_df = C2_state_df.drop('Gross State Domestic Product')

C2_state_df['% Total Conribution per GSDP'] = (C2_state_df['Total Conribution'] / Total_GSDP)*100
C2_state_df = C2_state_df.sort_values(by = ['% Total Conribution per GSDP'], ascending = False)
C2_state_df 

# Sectors contributing to 80% 
Sectors_contributing_upto_80 = C2_state_df.cumsum(axis = 0)
Sectors_contributing_upto_80 = Sectors_contributing_upto_80[Sectors_contributing_upto_80['% Total Conribution per GSDP'] <= 82]
Sectors_contributing_upto_80 = Sectors_contributing_upto_80[['% Total Conribution per GSDP']] 
Sectors_contributing_upto_80
# Out:
# 639027294.0
# State                                              % Total Conribution per GSDP
# Manufacturing                                                           17.8191
# Real estate, ownership of dwelling & profession...                      32.9244
# Agriculture, forestry and fishing                                       47.0127
# Trade, repair, hotels and restaurants                                   57.2583
# Construction                                                            64.3501
# Other services                                                           70.683
# Transport, storage, communication & services re...                      76.7589

# %%
C2_state_df['% Total Conribution per GSDP'].plot.bar(figsize = (10,7))
plt.title('C2 State Total Contribution per GSDP')
plt.xlabel('Sectors', fontsize = 10)
plt.ylabel('% Total Conribution per GSDP', fontsize = 10)
# Out:
# Text(0, 0.5, '% Total Conribution per GSDP')

# %%
#Filtering C3 States
C3_state_df= index_df[index_df['Tag'] == 'C3']
C3_state_df = C3_state_df.T

C3_state_df = C3_state_df.drop('Tag')
C3_state_df = C3_state_df.drop('Per Capita GSDP (Rs.)')
C3_state_df = C3_state_df.drop('TOTAL GSVA at basic prices')
C3_state_df = C3_state_df.drop('Taxes on Products')
C3_state_df = C3_state_df.drop('Subsidies on products')
C3_state_df = C3_state_df.drop("Population ('00)")

C3_state_df['Total Conribution'] = C3_state_df.sum(axis = 1)
Total_GSDP = 0
Total_GSDP = C3_state_df['Total Conribution']['Gross State Domestic Product']
print(Total_GSDP)
C3_state_df = C3_state_df.drop('Gross State Domestic Product')

C3_state_df['% Total Conribution per GSDP'] = (C3_state_df['Total Conribution'] / Total_GSDP)*100
C3_state_df = C3_state_df.sort_values(by = ['% Total Conribution per GSDP'], ascending = False)
C3_state_df 

# Sectors contributing to 80 %
Sectors_contributing_upto_80 = C3_state_df.cumsum(axis = 0)
Sectors_contributing_upto_80 = Sectors_contributing_upto_80[Sectors_contributing_upto_80['% Total Conribution per GSDP'] <= 82]
Sectors_contributing_upto_80 = Sectors_contributing_upto_80[['% Total Conribution per GSDP']] 
Sectors_contributing_upto_80
# Out:
# 125319545.0
# State                                              % Total Conribution per GSDP
# Agriculture, forestry and fishing                                       21.8701
# Manufacturing                                                           35.7275
# Trade, repair, hotels and restaurants                                   46.1105
# Real estate, ownership of dwelling & profession...                      55.5413
# Construction                                                            64.3532
# Mining and quarrying                                                    71.8153
# Other services                                                          78.6778

# %%
C3_state_df['% Total Conribution per GSDP'].plot.bar(figsize = (10,7))
plt.title('C3 State Total Contribution per GSDP')
plt.xlabel('Sectors', fontsize = 10)
plt.ylabel('% Total Conribution per GSDP', fontsize = 10)
# Out:
# Text(0, 0.5, '% Total Conribution per GSDP')

# %%
#Filtering C4 States

C4_state_df= index_df[index_df['Tag'] == 'C4']
C4_state_df = C4_state_df.T

C4_state_df = C4_state_df.drop('Tag')
C4_state_df = C4_state_df.drop('Per Capita GSDP (Rs.)')
C4_state_df = C4_state_df.drop('TOTAL GSVA at basic prices')
C4_state_df = C4_state_df.drop('Taxes on Products')
C4_state_df = C4_state_df.drop('Subsidies on products')
C4_state_df = C4_state_df.drop("Population ('00)")

C4_state_df['Total Conribution'] = C4_state_df.sum(axis = 1)
Total_GSDP = 0
Total_GSDP = C4_state_df['Total Conribution']['Gross State Domestic Product']
print(Total_GSDP)
C4_state_df = C4_state_df.drop('Gross State Domestic Product')

C4_state_df['% Total Conribution per GSDP'] = (C4_state_df['Total Conribution'] / Total_GSDP)*100
C4_state_df = C4_state_df.sort_values(by = ['% Total Conribution per GSDP'], ascending = False)
C4_state_df 

# Sectors contributing upto 80%
Sectors_contributing_upto_80 = C4_state_df.cumsum(axis = 0)
Sectors_contributing_upto_80 = Sectors_contributing_upto_80[Sectors_contributing_upto_80['% Total Conribution per GSDP'] <= 82]
Sectors_contributing_upto_80 = Sectors_contributing_upto_80[['% Total Conribution per GSDP']] 
Sectors_contributing_upto_80
# Out:
# 233252066.0
# State                                              % Total Conribution per GSDP
# Agriculture, forestry and fishing                                       24.3235
# Trade, repair, hotels and restaurants                                    35.994
# Manufacturing                                                           46.6852
# Real estate, ownership of dwelling & profession...                      56.9823
# Construction                                                            66.6854
# Transport, storage, communication & services re...                      73.5802
# Other services                                                           80.243

# %%
C4_state_df['% Total Conribution per GSDP'].plot.bar(figsize = (10,7))
plt.title('C4 State Total Contribution per GSDP')
plt.xlabel('Sectors', fontsize = 10)
plt.ylabel('% Total Conribution per GSDP', fontsize = 10)
# Out:
# Text(0, 0.5, '% Total Conribution per GSDP')

# %% [markdown]
# Points to be noted:
#
# •	It must be observed that “Agriculture” sector is in top 2 for all the states. This sector contributes to a large amount of GDP for all the sectors.  Hence it can be said that if there is drought or limitation of water, it will affect GDP of all the states as well as India’s GDP.
# Hence special oversight and funds must be allocated for the “Agriculture” sector.
#
# •	C1 States also gets special contribution from “Real Estate “sector. From this we can conclude that people are moving to these states and this is giving rise to this sector. Also we can state that population of these states will grow rapidly, hence care must be taken that resources such as water supply are in check. If not then we need to work in that directions.
#
# •	For C2 States, “Manufacturing” sector is important while for C3 states its second important. From this we can say that people who work in industries are more likely to come to this city for work. In this case, they should be given proper attention and enough opportunities for job.
#
# •	Also C3 States have “ Mining” Sector contributing which is clearly sign that people those who work on daily basis are more in these cities. If more efforts are put here, mining sector can become top sector for C3 States.
#
# •	Mining Sector, Construction Sector are among sectors those perform poorly for all states. This condition can be improved by providing more funds for these sectors and creating new job opportunities for people.

# %% [markdown]
# ## Part-II: GDP and Education Dropout Rates

# %%
dropout_df_data
dropout_rates = pd.read_csv(r'C:\Users\ACER\Desktop\MS\GDP Assignment\rs_session243_au570_1.1.csv')

# %%
# Select the required columns only from the dataframe which consists of Dropout rates
dropout_rates = dropout_rates[['Level of Education - State','Primary - 2014-2015.1','Upper Primary - 2014-2015','Secondary - 2014-2015']]

# %%
# Rename the columns to "State"
dropout_rates.rename(columns={ dropout_rates.columns[0]: "State"}, inplace = True)

# Rename the column to "Primary - 2014-2015"
dropout_rates.rename(columns={ dropout_rates.columns[1]: "Primary - 2014-2015" }, inplace = True)

# %%
#Drop the union territories
rows = [0,5,7,8,9,18,26]
dropout_rates = dropout_rates.drop (rows)

# %%
#Fill NA values with 0 which is safe way to clean the data without 
#introducing deviations in to the data
dropout_rates.fillna(0, inplace = True)

# %%
# Names from Part 1 Dataframe are not matching to the dropout data
# Rename the state names those are not matching with the suitable values

dropout_rates.loc['Andhra Pradesh', 'State'] = 'Andhra_Pradesh'
dropout_rates.loc['Arunachal Pradesh', 'State'] = 'Arunachal_Pradesh'
dropout_rates.loc['Uttar Pradesh', 'State'] = 'Uttar_Pradesh'
dropout_rates.loc['Tamil_Nadu', 'State'] = 'Tamil_Nadu'
dropout_rates.loc['Madhya Pradesh', 'State'] = 'Madhya_Pradesh'
dropout_rates.loc['Himachal Pradesh', 'State'] = 'Himachal_Pradesh'
dropout_rates.loc['Chhatisgarh', 'State'] = 'Chhattisgarh'
dropout_rates.loc['Uttrakhand', 'State'] = 'Uttarakhand'

# %%
#Merge the Part1 Data with the dropout data with States as Key

final_dropout_rate_data = dropout_df_data.merge(dropout_rates, on = 'State', how = 'inner')
final_dropout_rate_data.fillna(0, inplace = True)

# %% [markdown]
# #### Primary Vs Dropout Rates

# %%
# Extract the 'State','% Primary','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015' values
cor_df = final_dropout_rate_data[['State','% Primary','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']]

# Calculate the correaltion between 'State','% Primary','Primary - 2014-2015','Upper Primary - 2014-2015',
#'Secondary - 2014-2015 columns
cor = cor_df.corr()
cor

# Plot a heatmap which will give the visually represent the correlation between values
# figure size
plt.figure(figsize=(10,8))

# heatmap
sns.heatmap(cor, cmap="YlGnBu", annot=True)
plt.show()

# %% [markdown]
# Referring above Heatmap plotted for " % Primary " Vs "Dropout Rates (Primary,Upper Primary, Secondary)":
#
# It can be seen that upper primary is positively correlated with % Primary which means if Primary contribution increases, upper primary drops will increase and vice versa.
#
# In case of "Secondary", the correlation is negative meaning, increase in % Primary will decrease the dropout rates of Secondary.

# %% [markdown]
# #### Secondary Vs Dropout Rates

# %%
# Extract the 'State','% Secondary','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015' values
cor_df = final_dropout_rate_data[['State','% Secondary','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']]

# Calculate the correlation
cor = cor_df.corr()

# Plot heatmap for visualization
# figure size
plt.figure(figsize=(10,8))

# heatmap
sns.heatmap(cor, cmap="YlGnBu", annot=True)
plt.show()

# %% [markdown]
# In case of " % Secondary" contributions, dropout will decrease for Primary, Secondary, Upper Primary if secondary contributons increase.

# %% [markdown]
# #### Tertiary Vs Dropout Rates

# %%
# Extract the 'State','% Tertiary','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015' values
cor_df = final_dropout_rate_data[['State','% Tertiary','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']]

#Calculate correlation
cor = cor_df.corr()

# Plot heatmap
# figure size
plt.figure(figsize=(10,8))

# heatmap
sns.heatmap(cor, cmap="YlGnBu", annot=True)
plt.show()

# %% [markdown]
# It can be seen that, behaviur of " % Tertiary" contributions is opposite of "% Secondary" contributions.
#
# In case of secondary, dropouts were decreasing if contribution increased, but in case of tertiary contributions, dropout rate will increase if contributions increases.
#
# hence it can be said that, tertiary sectors are manual labour sectors where raw manpower is required mainly employing children's above age of 14 due to which dropout rate is increasing.

# %% [markdown]
# #### Population Vs Dropout Rates

# %%
#Extract the 'State','Population','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015' values
cor_df = final_dropout_rate_data[['State',"Population ('00)",'Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']]

cor = cor_df.corr()

# Plot heatmap
# figure size
plt.figure(figsize=(10,8))

# heatmap
sns.heatmap(cor, cmap="YlGnBu", annot=True)
plt.show()

# %% [markdown]
# #### Insights

# %% [markdown]
# After analyzing the data for % Primary, % Secondary, % Tertiary contributions, its safe to say that Tertiary Sectors are manual labor sectors. These sectors need attention to be provided as childrens working in these sectors are not able to focus on study.
# Due to work pressure and poor financial conditions, dropout rate of Primary, Secondary, Upper Primary is more compared to other sectors.

# %% [markdown]
# Hence more attention needs to be given to this sector which will benefit to create the educated and efficient labor force.
